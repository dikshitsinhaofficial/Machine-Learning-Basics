# %% [markdown]
# <a href="https://colab.research.google.com/github/dikshitsinhaofficial/Machine-Learning-Basics/blob/main/Experiment_2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
df=pd.read_csv('/content/height-weight.csv')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4999 entries, 0 to 4998
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Height  4999 non-null   float64
#  1   Weight  4999 non-null   float64
# dtypes: float64(2)
# memory usage: 78.2 KB

# %%
df.head(15)
# Out:
#        Height      Weight
# 0   68.781904  162.310473
# 1   74.110105  212.740856
# 2   71.730978  220.042470
# 3   69.881796  206.349801
# 4   67.253016  152.212156
# 5   68.785081  183.927889
# 6   68.348516  167.971111
# 7   67.018950  175.929440
# 8   63.456494  156.399676
# 9   71.195382  186.604926
# 10  71.640805  213.741170
# 11  64.766329  167.127461
# 12  69.283070  189.446181
# 13  69.243732  186.434168
# 14  67.645620  172.186930

# %%
plt.scatter(df['Weight'],df['Height'])
plt.xlabel("Weight")
plt.ylabel("Height")
# Out:
# Text(0, 0.5, 'Height')

# %%
X=df['Weight']
y=df['Height']

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=0.20,random_state=42)

# %%
y_train
# Out:
# 1738    69.762879
# 4943    67.809015
# 2916    63.786402
# 1595    66.628435
# 3214    69.634527
#           ...
# 4426    70.643193
# 466     68.478002
# 3092    67.467771
# 3772    67.903612
# 860     68.561751
# Name: Height, Length: 3999, dtype: float64

# %%
y_test
# Out:
# 84      71.079018
# 2470    72.963161
# 2804    71.892218
# 4987    71.046562
# 4924    69.388732
#           ...
# 4486    68.485214
# 1918    70.404724
# 4696    70.876667
# 3360    69.862057
# 3886    73.884576
# Name: Height, Length: 1000, dtype: float64

# %%
from sklearn.preprocessing import StandardScaler
scaler=StandardScaler()
X_train=scaler.fit_transform(X_train.reshape(-1,1))
X_test=scaler.transform(X_test.reshape(-1,1))

# %%
plt.scatter(X_train,y_train)
