# %% [markdown]
# <a href="https://colab.research.google.com/github/dikshitsinhaofficial/Machine-Learning-Basics/blob/main/ML_TRAINING.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=pd.read_csv('/content/laptop_data.csv')

# %%
df.head()
# Out:
#   Unnamed: 0 Company   TypeName Inches  ScreenResolutio  \
# 0          0   Apple  Ultrabook   13.3  IPS Panel Retin
# 1          1   Apple  Ultrabook   13.3         1440x900
# 2          2      HP   Notebook   15.6  Full HD 1920x10
# 3          3   Apple  Ultrabook   15.4  IPS Panel Retin
# 4          4   Apple  Ultrabook   13.3  IPS Panel Retin
#
#                                 Cpu
# 0  IDntisepl lCaoy r2e5 i650 2x.136
# 1                 Intel Core i5 1.8
# 2                I0ntel Core i5 720
# 3  IDntisepl lCaoy r2e8 i870 2x.178
# 4   IDntisepl lCaoy r2e5 i650 3x.16

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1303 entries, 0 to 1302
# Data columns (total 12 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Unnamed: 0        1303 non-null   int64
#  1   Company           1303 non-null   object
#  2   TypeName          1303 non-null   object
#  3   Inches            1303 non-null   float64
#  4   ScreenResolution  1303 non-null   object
#  5   Cpu               1303 non-null   object
#  6   Ram               1303 non-null   object
#  7   Memory            1303 non-null   object
#  8   Gpu               1303 non-null   object
#  9   OpSys             1303 non-null   object
#  10  Weight            1303 non-null   object
#  11  Price             1303 non-null   float64
# dtypes: float64(2), int64(1), object(9)
# memory usage: 122.3+ KB

# %%
df.isnull().sum()
# Out:
# Company             0
# TypeName            0
# Inches              0
# ScreenResolution    0
# Cpu                 0
# Ram                 0
# Memory              0
# Gpu                 0
# OpSys               0
# Weight              0
# Price               0
# dtype: int64

# %%
    df.drop(columns=['Unnamed: '], inplace=True)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /tmp/ipython-input-2898714539.py in <cell line: 0>()
# ----> 1 df.drop(columns=['Unnamed: '], inplace=True)
#
# /usr/local/lib/python3.12/dist-packages/pandas/core/frame.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    5579                 weight  1.0     0.8
#    5580         """
# -> 5581         return super().drop(
#    5582             labels=labels,
#    5583             axis=axis,
#
# /usr/local/lib/python3.12/dist-packages/pandas/core/generic.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    4786         for axis, labels in axes.items():
#    4787             if labels is not None:
# -> 4788                 obj = obj._drop_axis(labels, axis, level=level, errors=errors)
#    4789
#    4790         if inplace:
#
# ...

# %%
df['Ram']=df['Ram'].str.replace('GB',"")
df['Ram']=df['Ram'].str.replace('GB',"")

# %%
import seaborn as sns

# %%
sns.distplot(df['Price'])
# Out:
# /tmp/ipython-input-834922981.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['Price'])
# <Axes: xlabel='Price', ylabel='Density'>

# %%
df['Company'].value_counts().plot(kind='bar')
# Out:
# <Axes: xlabel='Company'>

# %%
sns.barplot(x=df['Company'], y=df['TypeName'])
plt.xticks(rotation='vertical')
plt.show()

# %%
df['TypeName'].value_counts().plot(kind='bar')
# Out:
# <Axes: xlabel='TypeName'>

# %%
sns.displot(df['Inches'])

# %%
sns.barplot(x=df['Company'], y=df['Price'])
plt.xticks(rotation='vertical')
plt.show()

# %%
sns.scatterplot(x=df['Inches'], y=df['Price'])
# Out:
# <Axes: xlabel='Inches', ylabel='Price'>

# %%
df['ScreenResolution'].value_counts()
# Out:
# ScreenResolution
# Full HD 1920x1080                                507
# 1366x768                                         281
# IPS Panel Full HD 1920x1080                      230
# IPS Panel Full HD / Touchscreen 1920x1080         53
# Full HD / Touchscreen 1920x1080                   47
# 1600x900                                          23
# Touchscreen 1366x768                              16
# Quad HD+ / Touchscreen 3200x1800                  15
# IPS Panel 4K Ultra HD 3840x2160                   12
# IPS Panel 4K Ultra HD / Touchscreen 3840x2160     11
# 4K Ultra HD / Touchscreen 3840x2160               10
# IPS Panel 1366x768                                 7
# Touchscreen 2560x1440                              7
# 4K Ultra HD 3840x2160                              7
# IPS Panel Retina Display 2304x1440                 6
# IPS Panel Retina Display 2560x1600                 6
# Touchscreen 2256x1504                              6
# ...

# %%
df['TypeNames']=df['ScreenResolution'].apply(lambda x:1 if'Touchscreen' in x else 0)
df.sample(6)
# Out:
#      Company     TypeName  Inches                 ScreenResolution  \
# 433   Lenovo  Workstation    15.6  IPS Panel 4K Ultra HD 3840x2160
# 20      Asus      Netbook    11.6                         1366x768
# 524     Dell     Notebook    17.3      IPS Panel Full HD 1920x1080
# 53        HP     Notebook    13.3                Full HD 1920x1080
# 515     Asus      Netbook    11.6                         1366x768
# 1189    Acer       Gaming    17.3      IPS Panel Full HD 1920x1080
#
#                                        Cpu Ram                Memory  \
# 433             Intel Core i7 7600U 2.8GHz  16             512GB SSD
# 20             Intel Atom x5-Z8350 1.44GHz   2    32GB Flash Storage
# 524             Intel Core i5 8250U 1.6GHz   8  128GB SSD +  1TB HDD
# 53              Intel Core i7 8550U 1.8GHz   8             512GB SSD
# 515   Intel Celeron Dual Core N3350 1.1GHz   2    32GB Flash Storage
# 1189           Intel Core i7 7700HQ 2.8GHz  16  256GB SSD +  1TB HDD
#
# ...

# %%
df['Touchscreen'].value_counts().plot(kind='bar')
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /usr/local/lib/python3.12/dist-packages/pandas/core/indexes/base.py in get_loc(self, key)
#    3804         try:
# -> 3805             return self._engine.get_loc(casted_key)
#    3806         except KeyError as err:
#
# index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Touchscreen'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# /tmp/ipython-input-1891934396.py in <cell line: 0>()
# ----> 1 df['Touchscreen'].value_counts().plot(kind='bar')
#
# ...

# %%
new=df['ScreenResolution'].str.split('x', n=1,expand=True)
new
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipython-input-4074985165.py in <cell line: 0>()
# ----> 1 new=df['ScreenResolution'].str.split('x', n=1,expand=True)
#       2 new
#
# NameError: name 'df' is not defined

# %% [markdown]
# df.show()

# %%
df.head()
# Out:
#   Company   TypeName  Inches                    ScreenResolution  \
# 0   Apple  Ultrabook    13.3  IPS Panel Retina Display 2560x1600
# 1   Apple  Ultrabook    13.3                            1440x900
# 2      HP   Notebook    15.6                   Full HD 1920x1080
# 3   Apple  Ultrabook    15.4  IPS Panel Retina Display 2880x1800
# 4   Apple  Ultrabook    13.3  IPS Panel Retina Display 2560x1600
#
#                           Cpu Ram               Memory  \
# 0        Intel Core i5 2.3GHz   8            128GB SSD
# 1        Intel Core i5 1.8GHz   8  128GB Flash Storage
# 2  Intel Core i5 7200U 2.5GHz   8            256GB SSD
# 3        Intel Core i7 2.7GHz  16            512GB SSD
# 4        Intel Core i5 3.1GHz   8            256GB SSD
#
#                             Gpu  OpSys  Weight        Price  TypeNames
# 0  Intel Iris Plus Graphics 640  macOS  1.37kg   71378.6832          0
# 1        Intel HD Graphics 6000  macOS  1.34kg   47895.5232          0
# ...

# %%
df['X_res']= new[0]
df['Y_res']= new[1]

# %%
df.sample(5)
# Out:
#      Company  TypeName  Inches             ScreenResolution  \
# 643     Asus    Gaming    15.6  IPS Panel Full HD 1920x1080
# 631     Dell    Gaming    15.6            Full HD 1920x1080
# 818     Dell    Gaming    17.3  IPS Panel Full HD 1920x1080
# 220     Dell  Notebook    15.6            Full HD 1920x1080
# 1238     MSI    Gaming    15.6            Full HD 1920x1080
#
#                               Cpu Ram                Memory  \
# 643   Intel Core i7 7700HQ 2.8GHz   8               1TB HDD
# 631   Intel Core i7 7700HQ 2.8GHz  16  256GB SSD +  1TB HDD
# 818   Intel Core i7 7700HQ 2.8GHz  16  128GB SSD +  1TB HDD
# 220    Intel Core i5 8250U 1.6GHz   8             256GB SSD
# 1238  Intel Core i7 6700HQ 2.6GHz   8  128GB SSD +  1TB HDD
#
#                              Gpu       OpSys  Weight        Price  TypeNames  \
# 643   Nvidia GeForce GTX 1050 Ti       No OS   2.5kg   62284.3200          0
# 631   Nvidia GeForce GTX 1050 Ti  Windows 10  2.62kg   78801.1200          0
# ...

# %%
df['X_res']=df['X_res'].str.replace(',','').str.findall(r'(\d+\.?)
# Out:
#   File "/tmp/ipython-input-1309144823.py", line 1
#     df['X_res']=df['X_res'].str.replace(',','').str.findall(r'(\d+\.?)
#                                                             ^
# SyntaxError: unterminated string literal (detected at line 1)

# %%
model training and deployment
# Out:
#   File "/tmp/ipython-input-1968693618.py", line 1
#     model training and deployment
#           ^
# SyntaxError: invalid syntax
